s,s,s,s,s,s,s,se,se,nw,s,s,se,n,s,se,ne,s,s,s,ne,s,se,nw,s,s,s,s,n,ne,s,se,se,s,s,ne,s,sw,s,s,s,se,s,s,s,se,ne,s,s,s,s,se,s,s,s,se,s,s,s,se,s,s,nw,s,s,nw,s,se,sw,s,s,se,s,s,se,se,s,se,se,s,s,se,sw,se,se,se,se,se,s,s,s,s,se,se,ne,se,s,ne'
  INPUT = INPUT.split(',')
  x=0; y=0
  cells = [(x, y)]
  for move in INPUT:
    if move == 'n':
      x += 0
      y += 1
    elif move == 's':
      x -= 0
      y -= 1
    elif move == 'ne':
      x += 1
      y += 0.5
    elif move == 'se':
      x += 1
      y -= 0.5
    elif move == 'nw':
      x -= 1
      y += 0.5
    elif move == 'sw':
      x -= 1
      y -= 0.5
    cells.append((x, y))
  print(cells)

  x, y = cells[-1]
  return [a[0] for a in cells], [a[1] for a in cells]

x, y = one_2()
# Out:
# [(0, 0), (1, -0.5), (2, 0.0), (3, 0.5), (3, 1.5), (3, 2.5), (3, 3.5), (3, 4.5), (3, 5.5), (3, 6.5), (2, 7.0), (1, 7.5), (0, 8.0), (1, 7.5), (0, 8.0), (-1, 8.5), (-2, 8.0), (-1, 7.5), (-2, 8.0), (-3, 7.5), (-4, 8.0), (-3, 7.5), (-4, 7.0), (-4, 6.0), (-5, 5.5), (-5, 4.5), (-5, 3.5), (-6, 3.0), (-6, 2.0), (-7, 1.5), (-8, 1.0), (-7, 1.5), (-8, 1.0), (-8, 0.0), (-9, -0.5), (-9, -1.5), (-10, -2.0), (-11, -1.5), (-11, -2.5), (-11, -3.5), (-11, -4.5), (-11, -5.5), (-11, -6.5), (-11, -7.5), (-12, -8.0), (-12, -9.0), (-12, -10.0), (-12, -9.0), (-13, -8.5), (-13, -9.5), (-13, -10.5), (-12, -11.0), (-11, -11.5), (-10, -12.0), (-10, -13.0), (-11, -12.5), (-10, -13.0), (-10, -14.0), (-9, -14.5), (-10, -14.0), (-9, -14.5), (-8, -15.0), (-8, -14.0), (-7, -14.5), (-6, -15.0), (-5, -15.5), (-4, -16.0), (-3, -16.5), (-2, -17.0), (-1, -17.5), (0, -17.0), (-1, -17.5), (-2, -17.0), (-1, -16.5), (-1, -15.5), (0, -16.0), (-1, -16.5), (-2, -16.0), (-1, -15.5), (0, -16.0), (1, -16.5), (2, -16.0), (1, -16.5), 
# ...

# %%
for i, pt in enumerate(zip(x, y)):
  x_i, y_i = pt
  plt.text(x_i, y_i, f'{i}', fontsize=9, ha='right')
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.grid(markevery=1)
plt.minorticks_on()
plt.show()
